# %%
import pandas as pd
import numpy as np
import folium
from geopy.geocoders import Nominatim

# %%
county = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/latimes-county-totals.csv')

county.head()
# Out:
#          date        county  fips  confirmed_cases  deaths  \
# 0  2020-01-26       Alameda     1                0       0
# 1  2020-01-26     Calaveras     9                0       0
# 2  2020-01-26  Contra Costa    13                0       0
# 3  2020-01-26      Humboldt    23                0       0
# 4  2020-01-26   Los Angeles    37                1       0
#
#    new_confirmed_cases  new_deaths
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                  NaN         NaN
# 3                  NaN         NaN
# 4                  NaN         NaN

# %%
county['date'] = pd.to_datetime(county['date'])

grouped_by_county = county.iloc[county.groupby('county')['date'].agg(pd.Series.idxmax)].copy()

# %%
grouped_by_county
# Out:
#            date           county  fips  confirmed_cases  deaths  \
# 3500 2020-05-11          Alameda     1             2101      71
# 3501 2020-05-11           Alpine     3                1       0
# 3502 2020-05-11           Amador     5                8       0
# 3503 2020-05-11            Butte     7               20       0
# 3504 2020-05-11        Calaveras     9               13       0
# 3505 2020-05-11           Colusa    11                3       0
# 3506 2020-05-11     Contra Costa    13             1048      32
# 3507 2020-05-11        Del Norte    15                3       0
# 3508 2020-05-11        El Dorado    17               56       0
# 3509 2020-05-11           Fresno    19              945       9
# 3510 2020-05-11            Glenn    21                6       0
# 3511 2020-05-11         Humboldt    23               61       0
# 3512 2020-05-11         Imperial    25              564      12
# 3513 2020-05-11             Inyo    27               19       1
# 3514 2020-05-11             Kern    29             1286      15
# 3515 2020-05-11            Kings    31              319       1
# 3516 2020-05-11             Lake    33                8       0
# 3517 2020-05-11           Lassen    35                0       0
# 3518 2020-05-11      Los Angeles    37            32269    1570
# 3519 2020-05-11           Madera    39               67       2
# 3520 2020-05-11            Marin    41              265      14
# 3521 2020-05-11         Mariposa    43               15       0
# 3522 2020-05-11        Mendocino    45               12       0
# 3523 2020-05-11           Merced    47              173       3
# 3524 2020-05-11            Modoc    49                0       0
# 3525 2020-05-11             Mono    51               32       1
# 3526 2020-05-11         Monterey    53              288       6
# 3527 2020-05-11             Napa    55               79       3
# 3528 2020-05-11           Nevada    57               41       1
# 3529 2020-05-11           Orange    59             3557      76
# 3530 2020-05-11           Placer    61              170       8
# 3531 2020-05-11           Plumas    63                4       0
# 3532 2020-05-11        Riverside    65             5189     217
# 3533 2020-05-11       Sacramento    67             1173      50
# 3534 2020-05-11       San Benito    69               56       2
# 3535 2020-05-11   San Bernardino    71             3015     115
# 3536 2020-05-11        San Diego    73             5065     175
# 3537 2020-05-11    San Francisco    75             1954      35
# 3538 2020-05-11      San Joaquin    77              621      29
# 3539 2020-05-11  San Luis Obispo    79              226       1
# 3540 2020-05-11        San Mateo    81             1464      56
# 3541 2020-05-11    Santa Barbara    83             1362      11
# 3542 2020-05-11      Santa Clara    85             2341     129
# 3543 2020-05-11       Santa Cruz    87              141       2
# 3544 2020-05-11           Shasta    89               32       4
# 3545 2020-05-11           Sierra    91                0       0
# 3546 2020-05-11         Siskiyou    93                5       0
# 3547 2020-05-11           Solano    95              379      10
# 3548 2020-05-11           Sonoma    97              312       4
# 3549 2020-05-11       Stanislaus    99              508      21
# 3550 2020-05-11           Sutter   101               34       2
# 3551 2020-05-11           Tehama   103                1       1
# 3552 2020-05-11          Trinity   105                1       0
# 3553 2020-05-11           Tulare   107             1159      50
# 3554 2020-05-11         Tuolumne   109                2       0
# 3555 2020-05-11          Ventura   111              678      19
# 3556 2020-05-11             Yolo   113              174      20
# 3557 2020-05-11             Yuba   115               21       1
#
#       new_confirmed_cases  new_deaths   latitude   longitude
# 3500                 37.0         0.0  37.609029 -121.899142
# 3501                  0.0         0.0  38.589393 -119.834501
# 3502                  0.0         0.0  38.449089 -120.591102
# 3503                  2.0         0.0  39.651927 -121.585844
# 3504                  0.0         0.0  38.255818 -120.498149
# 3505                  0.0         0.0  39.146558 -122.220956
# 3506                  0.0         1.0  37.903481 -121.917535
# 3507                  0.0         0.0  41.726177 -123.913280
# 3508                  2.0         0.0  38.757414 -120.527613
# 3509                 60.0         0.0  36.729529 -119.708861
# 3510                  0.0         0.0  39.591277 -122.377866
# 3511                  4.0         0.0  40.599742 -123.899773
# 3512                 52.0         0.0  33.030549 -115.359567
# 3513                  0.0         0.0  36.559533 -117.407471
# 3514                 32.0         0.0  35.314570 -118.753822
# 3515                 32.0         0.0  36.078481 -119.795634
# 3516                  0.0         0.0  36.701463 -118.755997
# 3517                  0.0         0.0  40.768558 -120.730998
# 3518                566.0        39.0  34.053691 -118.242767
# 3519                  0.0         0.0  36.941812 -120.171438
# 3520                  4.0         0.0  38.040914 -122.619964
# 3521                  0.0         0.0  37.570148 -119.903659
# 3522                  0.0         0.0  39.317649 -123.412640
# 3523                 10.0         0.0  37.164154 -120.767860
# 3524                  0.0         0.0  41.545049 -120.743600
# 3525                  3.0         0.0  37.953393 -118.939876
# 3526                  9.0         0.0  36.223108 -121.387743
# 3527                  0.0         1.0  38.297137 -122.285529
# 3528                  0.0         0.0  39.354033 -120.808984
# 3529                 55.0         0.0  33.750038 -117.870493
# 3530                  1.0         0.0  39.101206 -120.765061
# 3531                  0.0         0.0  39.943099 -120.805952
# 3532                150.0        12.0  33.953355 -117.396162
# 3533                  6.0         0.0  38.581572 -121.494400
# 3534                  1.0         0.0  36.624809 -121.117738
# 3535                 51.0         1.0  34.825302 -116.083314
# 3536                139.0         0.0  32.717421 -117.162771
# 3537                 11.0         1.0  37.779026 -122.419906
# 3538                  9.0         0.0  37.937290 -121.277372
# 3539                  6.0         0.0  35.354021 -120.375716
# 3540                 39.0         0.0  37.496904 -122.333057
# 3541                 54.0         0.0  34.422132 -119.702667
# 3542                  2.0         0.0  37.233325 -121.684635
# 3543                  0.0         0.0  37.050096 -121.990591
# 3544                  1.0         0.0  40.796512 -121.997919
# 3545                  0.0         0.0  39.584907 -120.530573
# 3546                  0.0         0.0  41.500722 -122.544354
# 3547                 28.0         3.0  38.221894 -121.916355
# 3548                  3.0         1.0  38.511080 -122.847339
# 3549                  7.0         0.0  37.550087 -121.050143
# 3550                  1.0         0.0  38.950967 -121.697088
# 3551                  0.0         0.0  40.125133 -122.201553
# 3552                  0.0         0.0  40.605326 -123.171268
# 3553                 19.0         2.0  36.251647 -118.852583
# 3554                  0.0         0.0  38.056944 -119.991935
# 3555                 12.0         0.0  34.445825 -119.077936
# 3556                  1.0         0.0  38.718454 -121.905900
# 3557                  1.0         0.0  39.283975 -121.355682

# %%
geolocater = Nominatim(user_agent='jonathancheung12@yahoo.com')

latitudes = []
longitudes = []
for i in grouped_by_county['county']:
    location = geolocater.geocode(i+', California')
    latitudes.append(location.latitude)
    longitudes.append(location.longitude)

# %%
grouped_by_county['latitude'] = np.array(latitudes)
grouped_by_county['longitude'] = np.array(longitudes)

# %%
# California's coordinates: 36.7783 lat 119.4179 long
cali_map = folium.Map(location = [36.7783, -119.4179], zoom_start = 6)

# %%
for county, lat, lon, death, cases in zip(grouped_by_county['county'], grouped_by_county['latitude'], grouped_by_county['longitude'], grouped_by_county['deaths'], grouped_by_county['confirmed_cases']):
    folium.CircleMarker(
        [lat, lon],
        radius = 5,
        color = 'magenta',
        popup = f'{county} Deaths:{death} Cases:{cases}'
    ).add_to(cali_map)

# %%
cali_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
